# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# DATA SCIENCE

# %% [markdown]
# Everything about data science:-

# %% [markdown]
# DATA SCIENCE LANGUAGES : ["Python","Sql","R programming","Java","Julia","Scala"]

# %% [markdown]
# DATA SCIENCE LIBRARIES can be classified into Python libraries and R libraries:
#
# Python libraries include: ["Pandas","Numpy","Matplotlib","Scipi","Scikit-learn"]
#
# R libraries include: ["ggplot2","caret","forecast"]

# %% [markdown]
# DATA SCIENCE TOOLS:
#
# Jupyter Notebook
#
# RStudio
#
# Apache Spark
#
# Apache Hadoop
#
# GitHub
#
# Excel

# %% [markdown]
# DATA SCIENCE ARITHMETIC EXPRESSIONS USING PYTHON:
#
#
# x=10
# y=5
#
#
# Addition:
# result=x+y
#
# Subtraction:
# result=x-y
#
# Multiplication:
# result=x*y
#
# Remainder:
# result=x%y
#
# Quotient:
# result=x/y
#
# Exponent:
# result=x**y

# %% [markdown]
# DATA SCIENCE MULTIPLY AND ADD NUMBERS:
#
# x=10
# y=5
#
# Multiply:
#
# result=x*y
#
# print(result)
#
# """output:50"""
#
#
# Add:
#
# result=x+y
#
# print(result)
#
# """output:15"""

# %% [markdown]
# DATA SCIENCE CONVERTING MINUTES TO HOURS:
#
# x=int(input("Enter minutes to convert: "))
#
# hours=x/60
#
# print("Hours: ",hours)

# %% [markdown]
# DATA SCIENCE OBJECTIVES:
#
# Data extraction
#
# Data cleaning
#
# Data visualisation
#
# Data management
#
# Observing patterns of data to help in day to day life issues

# %% [markdown]
# AUTHOR'S NAME:
#
# AAKANKSHA JOSHI
